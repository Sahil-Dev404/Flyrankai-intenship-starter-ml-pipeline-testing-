# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"""
Lane: Freestyle - Growth/Recovery Prediction

I chose the growth / recovery prediction freeStyle direction because it focuses on predicting the future content performance rather than only analyzing historical trends . my research question is "CAN WE PREDICT WHETHER A WEBPAGE IS LIKELY TO GROW , RECOVER , REMAIN STABLE OR DECLINE IN THE NEXT TIME WINDOW USING ONLY THE HISTORICAL SEARCH PERFORMANCE AND CONTENT SIGNALS?"
this problem has strong practical value because content teams need to prioritze pages before traffic change occur, not after. by building a leakage aware predictive model with a time based features and future window labels, i aim to create a decison support system that helps identify high risk pages early and enables proactive content refresh and optimisation stratergies .
"""
# Out:
# '\nLane: Freestyle - Growth/Recovery Prediction\n\nI chose the growth / recovery prediction freeStyle direction because it focuses on predicting the future content performance rather than only analyzing historical trends . my research question is "CAN WE PREDICT WHETHER A WEBPAGE IS LIKELY TO GROW , RECOVER , REMAIN STABLE OR DECLINE IN THE NEXT TIME WINDOW USING ONLY THE HISTORICAL SEARCH PERFORMANCE AND CONTENT SIGNALS?"\nthis problem has strong practical value because content teams need to prioritze pages before traffic change occur, not after. by building a leakage aware predictive model with a time based features and future window labels, i aim to create a decison support system that helps identify high risk pages early and enables proactive content refresh and optimisation stratergies .\n'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
"""
the decison my works aim to improve is which webpages should be prioritized for proactive intervention before their search performance changes significantly. instead of reacting after traffic has already declined, the model predicts wheather a page is likely to grow , recover ,remian stable, or decline in the next evaluation window using historical search and content signals. the primary users of this are SEO specialists , content stratergists and digital marketing teams, who can use the predictions to decide wheather to refresh content, monitor performance, or maintain existing pages.

A wrong recommendation has a tangile business cost. A flase postive may cause teams to spend time and resources updating content that would have perfomed well without intervention. A false neagtive is potentially more expensive because it can allow valuable pages to lose search visiblity, clicks, and organic traffic before any action is taken. 
therefore, the model is intended as a decison support system that helps prioritize limited content resources rather than replace human judgement.
"""
# Out:
# '\nthe decison my works aim to improve is which webpages should be prioritized for proactive intervention before their search performance changes significantly. instead of reacting after traffic has already declined, the model predicts wheather a page is likely to grow , recover ,remian stable, or decline in the next evaluation window using historical search and content signals. the primary users of this are SEO specialists , content stratergists and digital marketing teams, who can use the predictions to decide wheather to refresh content, monitor performance, or maintain existing pages.\n\nA wrong recommendation has a tangile business cost. A flase postive may cause teams to spend time and resources updating content that would have perfomed well without intervention. A false neagtive is potentially more expensive because it can allow valuable pages to lose search visiblity, clicks, and organic traffic before any action is taken. \ntherefore, the model is intended as a decison support system that helps prioritize limited content resources rather than replace human judgement.\n'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df=pd.read_csv('../../data/raw/content_refresh_anonymized.csv')
df.head(2)
print("shape:",df.shape)
print("no.of columns",len(df.columns))
print(df.columns.tolist())
# Out:
# shape: (30000, 44)
# no.of columns 44
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
#Trend direction distribution
print(df['trend_direction'].value_counts())

print("\n Trend direction(%)") #after the normalisation
print((df["trend_direction"].value_counts(normalize=True) * 100).round(2))
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
#  Trend direction(%)
# trend_direction
# down      54.21
# stable    19.87
# up        14.63
# new        7.45
# flat       3.84
# Name: proportion, dtype: float64

# %%
# Trend percentage statistics
print(df["trend_pct"].describe())
# Out:
# count    26612.000000
# mean        -4.785969
# std        473.861780
# min       -100.000000
# 25%        -62.600000
# 50%        -33.500000
# 75%          0.000000
# max      44900.000000
# Name: trend_pct, dtype: float64

# %%
#position statistics
print(df["avg_position"].describe())
# Out:
# count    30000.00000
# mean        16.34238
# std         15.21679
# min          0.00000
# 25%          6.20000
# 50%         10.80000
# 75%         22.30000
# max        245.00000
# Name: avg_position, dtype: float64

# %%
# CTR statistics
print(df["ctr"].describe())
# Out:
# count    30000.000000
# mean         0.510733
# std          3.279162
# min          0.000000
# 25%          0.000000
# 50%          0.070000
# 75%          0.290000
# max        100.000000
# Name: ctr, dtype: float64

# %%
# content type distribution
print(df["content_type"].value_counts())
# Out:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
"""
this research aims to develop a decision support model that uses historical search performance, engagement and content characteristics to estimate whether a webpage is likely to grow, recover, remain stable or decline during a future evaluation window. the findings will identify observed patterns and predictive relationships within the available dataset, helping the content and SEO teams prioritize pages for review and resource allocation. Any recommendations produced by the model should be interpreted as directional guidance based on historical data rather than definitive predictions or automated decisions.

the model will not establish casual relationships between content characteristics and search perfomance, nor will it prove that a specific action(such as refreshing content or modifying metadata) directly causes improvements in rankings, traffic, or engagement. it also doest not model or predict google ranking algorithms, search engine behaviour, or future algorithm updates. the results are limited to the scope of the provided dataset and should be viewed as evidence based decision support, complementing the human expertise rather than replacing it.
"""
# Out:
# '\nthis research aims to develop a decision support model that uses historical search performance, engagement and content characteristics to estimate whether a webpage is likely to grow, recover, remain stable or decline during a future evaluation window. the findings will identify observed patterns and predictive relationships within the available dataset, helping the content and SEO teams prioritize pages for review and resource allocation. Any recommendations produced by the model should be interpreted as directional guidance based on historical data rather than definitive predictions or automated decisions.\n\nthe model will not establish casual relationships between content characteristics and search perfomance, nor will it prove that a specific action(such as refreshing content or modifying metadata) directly causes improvements in rankings, traffic, or engagement. it also doest not model or predict google ranking algorithms, search engine behaviour, or future algorithm updates. the results are limited to the scope of the provided dataset and should be viewed as evidence based decision support, complementing the human expertise rather than replacing it.\n'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

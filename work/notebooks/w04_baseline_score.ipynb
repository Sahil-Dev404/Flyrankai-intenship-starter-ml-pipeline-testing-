# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %% [markdown]
# Rule:
#
# >i also mentioned in the w01 notebook that the costliest mistake in this research is a False Negative:- missing a page that is about to decline costs more than reviveing a page that didnt need it. so before training any classifier , the baseline job is narrow and honest - flag pages worth reviewing because they look at risk of decline.
#
# >A page is worth flagging a review if:
# >1. it already earns real visibility (so a decline would actually cost something)
# >2. it has not been touched in a long period of time
# >3. it currently ranks poorly (weak position) or gets weak engagement despite >that visibility (visible but not converting)
#
# >Reason CODES the rule can emit (one row can carry more than one):
# >1. 'stale' -> days_since_last_optimized >= 180
# >2. 'weak position' -> march_avg_position > 20 (worse than the 75th pct we saw >in w01 EDA)
# >3. 'weak engagement' -> march_engagement_rate below the sample median
# >4. 'visible' -> march_impressions >= 500 (real traffic)
#
# >A row's priority score is simply how many of these fire, scaled by how much traffic is actually at stake (march_impressions) — more visible + more flags = reviewed first. This mirrors the building-baselines skill's own example (`score = stale * visible * impressions`), extended to more than one flag.

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
import pathlib
import numpy as np
import pandas as pd

FEATURES_PATH = pathlib.Path("../../data/processed/features_march_2026_leakage_checked.parquet")
df = pd.read_parquet(FEATURES_PATH)

print("Loaded:", df.shape)
required_cols = [
    "client_hash_id", "content_hash_id", "march_impressions", "march_avg_position",
    "march_engagement_rate", "days_since_last_optimized", "growth_state",
]
missing = [c for c in required_cols if c not in df.columns]
assert not missing, f"Expected columns missing from the w03 artifact: {missing}"
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import pandas as pd
#       5 FEATURES_PATH = pathlib.Path("../../data/processed/features_march_2026_leakage_checked.parquet")
# ----> 6 df = pd.read_parquet(FEATURES_PATH)
#       8 print("Loaded:", df.shape)
#       9 required_cols = [
#      10     "client_hash_id", "content_hash_id", "march_impressions", "march_avg_position",
#      11     "march_engagement_rate", "days_since_last_optimized", "growth_state",
#      12 ]
#
# File c:\Users\HP\anaconda3\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
# ...

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

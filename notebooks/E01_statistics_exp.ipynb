# %% [markdown]
# Here i am doing some statisitcs data analysis for the first notebook deliverable w01_research_question

# %% [markdown]
# 1. importing the dataset

# %%
import pandas as pd

df=pd.read_csv('../data/raw/content_refresh_anonymized.csv')
